# %% [markdown]
# ### 신용카드 사기 거래 탐지 경진대회 (Anomaly Detection)
# https://dacon.io/competitions/official/235930/data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/사기탐지
# Out:
# /content/drive/MyDrive/Colab Notebooks/사기탐지

# %%
#! pip install pycaret==2.3.5
#! pip install scipy==1.4.1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.neighbors import LocalOutlierFactor
from sklearn.metrics import f1_score, classification_report, confusion_matrix, precision_recall_fscore_support
from sklearn.ensemble import IsolationForest
from sklearn.covariance import EllipticEnvelope
import time

pd.set_option('mode.chained_assignment',  None)

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
val = pd.read_csv('val.csv')

# %% [markdown]
# * train: 비식별화된 신용카드 데이터, unlabeled
# * val: 정상, 사기 거래 여부 포함된 데이터. 학습 불가능
# * test: 제출 데이터
# * 심사 기준: macro f1-score

# %%
train.head()
# Out:
#    ID        V1        V2        V3        V4        V5        V6        V7  \
# 0   3 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 1   4 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 2   6 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 3   8 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 4   9 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 1  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 2  0.260314 -0.568671 -0.371407  1.341262  0.359894 -0.358091 -0.137134
# 3 -3.807864  0.615375  1.249376 -0.619468  0.291474  1.757964 -1.323865
# 4  0.851084 -0.392048 -0.410430 -0.705117 -0.110452 -0.286254  0.074355
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 1 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 2  0.517617  0.401726 -0.058133  0.068653 -0.033194  0.084968 -0.208254
# 3  0.686133 -0.076127 -1.222127 -0.358222  0.324505 -0.156742  1.943465
# 4 -0.328783 -0.210077 -0.499768  0.118765  0.570328  0.052736 -0.073425
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 1  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 2 -0.559825 -0.026398 -0.371427 -0.232794  0.105915  0.253844  0.081080
# 3 -1.015455  0.057504 -0.649709 -0.415267 -0.051634 -1.206921 -1.085339
# 4 -0.268092 -0.204233  1.011592  0.373205 -0.384157  0.011747  0.142404
#
#         V29       V30
# 0  4.983721 -0.994972
# 1  1.418291 -0.994972
# 2 -0.256131 -0.994960
# 3  0.262698 -0.994901
# 4  0.994900 -0.994901

# %%
val.head()
# Out:
#    ID        V1        V2        V3        V4        V5        V6        V7  \
# 0  10 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
# 1  22  0.962496  0.328461 -0.171479  2.109204  1.129566  1.696038  0.107712
# 2  63  1.145524  0.575068  0.194008  2.598192 -0.092210 -1.044430  0.531588
# 3  69  0.927060 -0.323684  0.387585  0.544474  0.246787  1.650358 -0.427576
# 4  83 -3.005237  2.600138  1.483691 -2.418473  0.306326 -0.824575  2.065426
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.069539 -0.736727 -0.366846  1.017614  0.836390  1.006844 -0.443523
# 1  0.521502 -1.191311  0.724396  1.690330  0.406774 -0.936421  0.983739
# 2 -0.241888 -0.896287  0.757952 -0.448937 -0.660863 -1.308522  0.788864
# 3  0.615371  0.226278 -0.225495  1.944545  1.385160 -0.479262  0.314166
# 4 -1.829347  4.009259  6.051521  2.572500  0.066851 -0.353574 -2.837136
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  0.150219  0.739453 -0.540980  0.476677  0.451773  0.203711 -0.246914
# 1  0.710911 -0.602232  0.402484 -1.737162 -2.027612 -0.269321  0.143997
# 2  0.320294  0.295404 -0.287878 -0.451453 -1.011446 -0.191050  0.011106
# 3  0.214167 -1.333716  1.002869 -2.119314 -1.053043 -0.185390 -0.040513
# 4  0.292227 -0.303774 -1.942303 -0.435450 -0.934016  2.456724 -0.852309
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0 -0.633753 -0.120794 -0.385050 -0.069733  0.094199  0.246219  0.083076
# 1  0.402492 -0.048508 -1.371866  0.390814  0.199964  0.016371 -0.014605
# 2 -0.119703 -0.076510  0.691320  0.633984  0.048741 -0.053192  0.016251
# 3  0.079359  0.096632 -0.992569  0.085096  0.377447  0.036096 -0.005960
# 4 -0.181268 -0.163747  0.515821  0.136318  0.460054 -0.251259 -1.105751
#
#         V29       V30  Class
# 0 -0.255991 -0.994878      0
# 1  0.168937 -0.994784      0
# 2  0.169496 -0.994502      0
# 3  0.331307 -0.994467      0
# 4 -0.287012 -0.994373      0

# %%
test.head()
# Out:
#         ID        V1        V2        V3        V4        V5        V6  \
# 0  AAAA0x1 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1  AAAA0x2  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2  AAAA0x5 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 3  AAAA0x7  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 4  AAAA0xc  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
#
#          V7        V8        V9       V10       V11       V12       V13  \
# 0  0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390
# 1 -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095
# 2  0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852
# 3 -0.005159  0.081213  0.464960 -0.099254 -1.416907 -0.153826 -0.751063
# 4  0.470455  0.538247 -0.558895  0.309755 -0.259116 -0.326143 -0.090047
#
#         V14       V15       V16       V17       V18       V19       V20  \
# 0 -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412
# 1 -0.143772  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083
# 2 -1.119670  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542
# 3  0.167372  0.050144 -0.443587  0.002821 -0.611987 -0.045575 -0.219633
# 4  0.362832  0.928904 -0.129487 -0.809979  0.359985  0.707664  0.125992
#
#         V21       V22       V23       V24       V25       V26       V27  \
# 0 -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1 -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2 -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422
# 3 -0.167716 -0.270710 -0.154104 -0.780055  0.750137 -0.257237  0.034507
# 4  0.049924  0.238422  0.009130  0.996710 -0.767315 -0.492208  0.042472
#
#         V28       V29       V30
# 0 -0.021053  1.783274 -0.994983
# 1  0.014724 -0.269825 -0.994983
# 2  0.215153  0.670579 -0.994960
# 3  0.005168 -0.237686 -0.994937
# 4 -0.054337 -0.167819 -0.994866

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113842 entries, 0 to 113841
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      113842 non-null  int64
#  1   V1      113842 non-null  float64
#  2   V2      113842 non-null  float64
#  3   V3      113842 non-null  float64
#  4   V4      113842 non-null  float64
#  5   V5      113842 non-null  float64
#  6   V6      113842 non-null  float64
#  7   V7      113842 non-null  float64
#  8   V8      113842 non-null  float64
#  9   V9      113842 non-null  float64
#  10  V10     113842 non-null  float64
#  11  V11     113842 non-null  float64
#  12  V12     113842 non-null  float64
#  13  V13     113842 non-null  float64
#  14  V14     113842 non-null  float64
#  15  V15     113842 non-null  float64
#  16  V16     113842 non-null  float64
#  17  V17     113842 non-null  float64
#  18  V18     113842 non-null  float64
#  19  V19     113842 non-null  float64
#  20  V20     113842 non-null  float64
#  21  V21     113842 non-null  float64
#  22  V22     113842 non-null  float64
#  23  V23     113842 non-null  float64
#  24  V24     113842 non-null  float64
#  25  V25     113842 non-null  float64
#  26  V26     113842 non-null  float64
#  27  V27     113842 non-null  float64
#  28  V28     113842 non-null  float64
#  29  V29     113842 non-null  float64
#  30  V30     113842 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 26.9 MB

# %%
train.isnull().sum()
# Out:
# ID     0
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# dtype: int64

# %%
train_df = train.drop(['ID'], axis=1)
test_df = test.drop(['ID'], axis=1)
val_df = val.drop(['ID', 'Class'], axis=1)

# %%
train_df.describe()
# Out:
#                   V1             V2             V3             V4  \
# count  113842.000000  113842.000000  113842.000000  113842.000000
# mean        0.000197       0.001289       0.009717      -0.004169
# std         1.951060       1.651064       1.496916       1.412633
# min       -56.407510     -72.715728     -32.454198      -5.600607
# 25%        -0.923479      -0.595602      -0.883877      -0.853728
# 50%         0.012074       0.066390       0.183868      -0.019359
# 75%         1.315373       0.801687       1.037120       0.742208
# max         2.454930      21.467203       4.187811      16.491217
#
#                   V5             V6             V7             V8  \
# count  113842.000000  113842.000000  113842.000000  113842.000000
# mean        0.000475       0.005141       0.005769      -0.002451
# std         1.367533       1.330583       1.204111       1.185504
# min       -42.147898     -26.160506     -41.506796     -50.943369
# 25%        -0.689853      -0.766094      -0.552071      -0.209492
# 50%        -0.054060      -0.272436       0.039036       0.020970
# 75%         0.614214       0.405285       0.568750       0.328303
# max        34.801666      23.917837      44.054461      20.007208
#
#                   V9            V10  ...            V21           V22  \
# count  113842.000000  113842.000000  ...  113842.000000  1.138420e+05
# mean       -0.002107       0.005209  ...      -0.001242  4.088347e-07
# std         1.095415       1.071337  ...       0.722001  7.238291e-01
# min       -13.434066     -24.403185  ...     -22.757540 -8.887017e+00
# 25%        -0.647477      -0.533477  ...      -0.229710 -5.402665e-01
# 50%        -0.052157      -0.090810  ...      -0.030281  8.345807e-03
# 75%         0.590705       0.455287  ...       0.186001  5.287508e-01
# max        10.392889      15.331742  ...      27.202839  8.361985e+00
#
#                  V23            V24            V25            V26  \
# count  113842.000000  113842.000000  113842.000000  113842.000000
# mean       -0.001317      -0.000884       0.001680      -0.000293
# std         0.636061       0.605854       0.520069       0.480979
# min       -44.807735      -2.824849     -10.295397      -1.855355
# 25%        -0.162180      -0.355582      -0.315470      -0.326160
# 50%        -0.012261       0.040573       0.018278      -0.052815
# 75%         0.147474       0.438225       0.353989       0.240838
# max        22.528412       4.022866       7.519589       3.119295
#
#                  V27            V28            V29            V30
# count  113842.000000  113842.000000  113842.000000  113842.000000
# mean       -0.000234      -0.000508       0.927253       0.116232
# std         0.399505       0.356130       3.412933       0.558161
# min        -9.895244      -9.617915      -0.307413      -0.994972
# 25%        -0.070847      -0.053249      -0.230560      -0.360304
# 50%         0.001502       0.011158      -0.000699      -0.002590
# 75%         0.091279       0.077851       0.768532       0.640653
# max        11.135740      33.847808     180.101027       1.034951
#
# [8 rows x 30 columns]

# %%
val_norm, val_fraud = val['Class'].value_counts()
val_contamination = val_fraud/val_norm
print("정상거래: %d, 사기거래: %d" %(val_norm, val_fraud))
print("비율: %5f" %(val_contamination))
# Out:
# 정상거래: 28432, 사기거래: 30
# 비율: 0.001055

# %%
train_df.hist(bins=50, figsize=(15, 15), edgecolor="black")
plt.show()

# %%
val_df.drop(['Class'], axis=1).hist(bins=50, figsize=(15, 15), edgecolor="black")
plt.show()

# %%
plt.figure(figsize=(30,5))
sns.boxplot(data=train_df)
plt.show()

# %%
def color_(value):
    if value < 0 :
        color = 'red'
    elif value == 1 :
        color = 'blue'
    else:
        color = 'green'
    return 'color: %s' % color
train_df.corr().style.applymap(color_)
# Out:
# <style type="text/css">
# #T_ddd50_row0_col0, #T_ddd50_row1_col1, #T_ddd50_row2_col2, #T_ddd50_row3_col3, #T_ddd50_row4_col4, #T_ddd50_row5_col5, #T_ddd50_row6_col6, #T_ddd50_row7_col7, #T_ddd50_row8_col8, #T_ddd50_row9_col9, #T_ddd50_row10_col10, #T_ddd50_row11_col11, #T_ddd50_row12_col12, #T_ddd50_row13_col13, #T_ddd50_row14_col14, #T_ddd50_row15_col15, #T_ddd50_row16_col16, #T_ddd50_row17_col17, #T_ddd50_row18_col18, #T_ddd50_row19_col19, #T_ddd50_row20_col20, #T_ddd50_row21_col21, #T_ddd50_row22_col22, #T_ddd50_row23_col23, #T_ddd50_row24_col24, #T_ddd50_row25_col25, #T_ddd50_row26_col26, #T_ddd50_row27_col27, #T_ddd50_row28_col28, #T_ddd50_row29_col29 {
#   color: blue;
# }
# #T_ddd50_row0_col1, #T_ddd50_row0_col3, #T_ddd50_row0_col7, #T_ddd50_row0_col10, #T_ddd50_row0_col12, #T_ddd50_row0_col19, #T_ddd50_row0_col20, #T_ddd50_row0_col22, #T_ddd50_row0_col24, #T_ddd50_row0_col26, #T_ddd50_row0_col29, #T_ddd50_row1_col0, #T_ddd50_row1_col2, #T_ddd50_row1_col4, #T_ddd50_row1_col5, #T_ddd50_row1_col6, #T_ddd50_row1_col7, #T_ddd50_row1_col8, #T_ddd50_row1_col9, #T_ddd50_row1_col11, #T_ddd50_row1_col12, #T_ddd50_row1_col13, #T_ddd50_row1_col15, #T_ddd50_row1_col16, #T_ddd50_row1_col17, #T_ddd50_row1_col19, #T_ddd50_row1_col20, #T_ddd50_row1_col21, #T_ddd50_row1_col22, #T_ddd50_row1_col25, #T_ddd50_row1_col26, #T_ddd50_row2_col1, #T_ddd50_row2_col3, #T_ddd50_row2_col7, #T_ddd50_row2_col10, #T_ddd50_row2_col19, #T_ddd50_row2_col21, #T_ddd50_row2_col22, #T_ddd50_row2_col23, #T_ddd50_row2_col24, #T_ddd50_row2_col25, #T_ddd50_row2_col26, #T_ddd50_row3_col0, #T_ddd50_row3_col2, #T_ddd50_row3_col4, #T_ddd50_row3_col5, #T_ddd50_row3_col6, #T_ddd50_row3_col7, #T_ddd50_row3_col8, #T_ddd50_row3_col9, #T_ddd50_row3_col11, #T_ddd50_row3_col12, #T_ddd50_row3_col13, #T_ddd50_row3_col14, #T_ddd50_row3_col15, #T_ddd50_row3_col16, #T_ddd50_row3_col17, #T_ddd50_row3_col18, #T_ddd50_row3_col23, #T_ddd50_row3_col24, #T_ddd50_row3_col25, #T_ddd50_row3_col27, #T_ddd50_row3_col28, #T_ddd50_row4_col1, #T_ddd50_row4_col3, #T_ddd50_row4_col10, #T_ddd50_row4_col12, #T_ddd50_row4_col14, #T_ddd50_row4_col18, #T_ddd50_row4_col21, #T_ddd50_row4_col23, #T_ddd50_row4_col26, #T_ddd50_row4_col29, #T_ddd50_row5_col1, #T_ddd50_row5_col3, #T_ddd50_row5_col7, #T_ddd50_row5_col10, #T_ddd50_row5_col12, #T_ddd50_row5_col14, #T_ddd50_row5_col18, #T_ddd50_row5_col19, #T_ddd50_row5_col20, #T_ddd50_row5_col22, #T_ddd50_row5_col27, #T_ddd50_row5_col28, #T_ddd50_row6_col1, #T_ddd50_row6_col3, #T_ddd50_row6_col7, #T_ddd50_row6_col10, #T_ddd50_row6_col18, #T_ddd50_row6_col19, #T_ddd50_row6_col20, #T_ddd50_row6_col22, #T_ddd50_row6_col24, #T_ddd50_row6_col25, #T_ddd50_row6_col27, #T_ddd50_row6_col28, #T_ddd50_row6_col29, #T_ddd50_row7_col0, #T_ddd50_row7_col1, #T_ddd50_row7_col2, #T_ddd50_row7_col3, #T_ddd50_row7_col5, #T_ddd50_row7_col6, #T_ddd50_row7_col11, #T_ddd50_row7_col12, #T_ddd50_row7_col13, #T_ddd50_row7_col15, #T_ddd50_row7_col16, #T_ddd50_row7_col17, #T_ddd50_row7_col20, #T_ddd50_row7_col21, #T_ddd50_row7_col22, #T_ddd50_row7_col23, #T_ddd50_row7_col25, #T_ddd50_row8_col1, #T_ddd50_row8_col3, #T_ddd50_row8_col10, #T_ddd50_row8_col18, #T_ddd50_row8_col23, #T_ddd50_row8_col25, #T_ddd50_row8_col27, #T_ddd50_row9_col1, #T_ddd50_row9_col3, #T_ddd50_row9_col10, #T_ddd50_row9_col14, #T_ddd50_row9_col18, #T_ddd50_row9_col19, #T_ddd50_row9_col21, #T_ddd50_row9_col23, #T_ddd50_row9_col27, #T_ddd50_row9_col29, #T_ddd50_row10_col0, #T_ddd50_row10_col2, #T_ddd50_row10_col4, #T_ddd50_row10_col5, #T_ddd50_row10_col6, #T_ddd50_row10_col8, #T_ddd50_row10_col9, #T_ddd50_row10_col11, #T_ddd50_row10_col13, #T_ddd50_row10_col14, #T_ddd50_row10_col15, #T_ddd50_row10_col16, #T_ddd50_row10_col17, #T_ddd50_row10_col21, #T_ddd50_row10_col25, #T_ddd50_row11_col1, #T_ddd50_row11_col3, #T_ddd50_row11_col7, #T_ddd50_row11_col10, #T_ddd50_row11_col18, #T_ddd50_row11_col20, #T_ddd50_row11_col21, #T_ddd50_row11_col23, #T_ddd50_row11_col25, #T_ddd50_row11_col27, #T_ddd50_row11_col29, #T_ddd50_row12_col0, #T_ddd50_row12_col1, #T_ddd50_row12_col3, #T_ddd50_row12_col4, #T_ddd50_row12_col5, #T_ddd50_row12_col7, #T_ddd50_row12_col14, #T_ddd50_row12_col15, #T_ddd50_row12_col16, #T_ddd50_row12_col17, #T_ddd50_row12_col21, #T_ddd50_row12_col27, #T_ddd50_row12_col28, #T_ddd50_row13_col1, #T_ddd50_row13_col3, #T_ddd50_row13_col7, #T_ddd50_row13_col10, #T_ddd50_row13_col14, #T_ddd50_row13_col18, #T_ddd50_row13_col20, #T_ddd50_row13_col22, #T_ddd50_row13_col24, #T_ddd50_row13_col26, #T_ddd50_row13_col27, #T_ddd50_row13_col28, #T_ddd50_row14_col3, #T_ddd50_row14_col4, #T_ddd50_row14_col5, #T_ddd50_row14_col9, #T_ddd50_row14_col10, #T_ddd50_row14_col12, #T_ddd50_row14_col13, #T_ddd50_row14_ ...

# %%
select_feature = ['V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V9', 'V10', 'V11', 'V12', 'V14', 'V16', 'V17', 'V18', 'V30']
#select_feature_val = ['V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V9', 'V10', 'V11', 'V12', 'V14', 'V16', 'V17', 'V18', 'V30', 'Class']

train_df = train_df[select_feature]
test_df = test_df[select_feature]
val_df = val[select_feature]

# %%
scaler = StandardScaler()
train_df.iloc[:,:] = scaler.fit_transform(train_df)
test_df.iloc[:,:] = scaler.fit_transform(test_df)
val_df.iloc[:,:] = scaler.fit_transform(val_df)

# %% [markdown]
# ## Models

# %%
def plot_confusion_matrix(cm,target_names,title='Confusion matrix',cmap=None,
                          normalize=False):
    import itertools
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
# https://www.kaggle.com/code/drscarlat/compare-6-unsupervised-anomaly-detection-models

# %%
val['Class'].value_counts()
# Out:
# 0    28432
# 1       30
# Name: Class, dtype: int64

# %% [markdown]
# ### Isolation Forest

# %%
# isolation forest
IF = IsolationForest(n_estimators=150, max_samples=len(train_df), contamination = val_contamination, max_features = 1, random_state=77)
IF.fit(train_df)

pred = IF.predict(val_df)
y = val['Class']

pred_if = [1 if i==-1 else 0 for i in pred]
val_score = f1_score(y, pred_if, average='macro')

print("Macro f1 score: %.5f" %(val_score))
print(classification_report(y, pred_if))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# Macro f1 score: 0.70308
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.41      0.40      0.41        30
#
#     accuracy                           1.00     28462
#    macro avg       0.71      0.70      0.70     28462
# weighted avg       1.00      1.00      1.00     28462

# %%
CM=confusion_matrix(y, pred_if)
plot_confusion_matrix(CM, 
                      normalize    = False,
                      target_names = ['Normal', 'Fraud'],
                      title        = "IsolationForest Confusion Matrix")

# %% [markdown]
# ### Local Outlier Factor

# %%
LOF = LocalOutlierFactor(contamination = val_contamination, novelty=True)
LOF.fit(train_df)

pred = LOF.predict(val_df)
y = val['Class'] 

pred_lof = [1 if i==-1 else 0 for i in pred]
val_score = f1_score(y, pred_lof, average='macro')

print("Macro f1 score: %.5f" %(val_score))
print(classification_report(y, pred_lof))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# Macro f1 score: 0.49940
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.00      0.00      0.00        30
#
#     accuracy                           1.00     28462
#    macro avg       0.50      0.50      0.50     28462
# weighted avg       1.00      1.00      1.00     28462

# %%
CM=confusion_matrix(y, pred_lof)
plot_confusion_matrix(CM, 
                      normalize    = False,
                      target_names = ['Normal', 'Fraud'],
                      title        = "LocalOutlierFactor Confusion Matrix")

# %%
# Optimize LOF hyperparameter n_neighbors for best f1

minRE = 700
maxRE = 1100
    
LofF1 = []

for TryRE in np.arange(minRE, maxRE, 100):
  y = val['Class'] 
  clf = LocalOutlierFactor(n_neighbors=TryRE, contamination = val_contamination, novelty=True)
  clf.fit(train_df)
  y_pred = clf.predict(val_df)
  
  y_pred_lof = [1 if i==-1 else 0 for i in y_pred]
  macro_f1 = f1_score(y, y_pred_lof, average='macro')
  
  print("F1 score on test", round(macro_f1,5), " with num neighbors ", TryRE)
  LofF1.append([TryRE, round(macro_f1,5)])
    
LofF1df = pd.DataFrame(LofF1, columns = ['NumNeighb', 'F1'])
LofF1df.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# F1 score on test 0.79289  with num neighbors  700
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# F1 score on test 0.78792  with num neighbors  800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-1ec3e873837a> in <module>
#       9   y = val['Class']
#      10   clf = LocalOutlierFactor(n_neighbors=TryRE, contamination = val_contamination, novelty=True)
# ---> 11   clf.fit(train_df)
#      12   y_pred = clf.predict(val_df)
#      13
#
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_lof.py in fit(self, X, y)
#     290         self.n_neighbors_ = max(1, min(self.n_neighbors, n_samples - 1))
#     291
# --> 292         self._distances_fit_X_, _neighbors_indices_fit_X_ = self.kneighbors(
#     293             n_neighbors=self.n_neighbors_
#     294         )
#
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     774             else:
#     775                 parallel_kwargs = {"prefer": "threads"}
# --> 776             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     777                 delayed(_tree_query_parallel_helper)(
#     778                     self._tree, X[s], n_neighbors, return_distance
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1083             # remaining jobs.
#    1084             self._iterating = False
# -> 1085             if self.dispatch_one_batch(iterator):
#    1086                 self._iterating = self._original_iterator is not None
#    1087
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     598     under PyPy.
#     599     """
# --> 600     return tree.query(*args, **kwargs)
#     601
#     602
#
# KeyboardInterrupt:

# %%
LofF1df.plot.line("NumNeighb","F1")
plt.xlim(500, 1000)
plt.title("F1 vs NumNeighb")
plt.show()

# %% [markdown]
# ### Robust Covariance (Elliptic Envelope)

# %%
EE = EllipticEnvelope(support_fraction = 0.994, contamination = val_contamination, random_state = 42)
EE.fit(train_df)

pred = EE.predict(val_df)
y = val['Class'] 

pred_ee = [1 if i==-1 else 0 for i in pred]
val_score_ee = f1_score(y, pred_ee, average='macro')

print("Macro f1 score: %.5f" %(val_score_ee))
print(classification_report(y, pred_ee))
# Out:
# Macro f1 score: 0.89275
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.85      0.73      0.79        30
#
#     accuracy                           1.00     28462
#    macro avg       0.92      0.87      0.89     28462
# weighted avg       1.00      1.00      1.00     28462

# %%
CM=confusion_matrix(y, pred_ee)
plot_confusion_matrix(CM, 
                      normalize    = False,
                      target_names = ['Normal', 'Fraud'],
                      title        = "EllipticEnvelope Confusion Matrix")

# %%
# Optimize EE hyperparameter for best f1

minRE = 0.992
maxRE = 0.998
    
EpsF1 = []

for TryRE in np.arange(minRE, maxRE, 0.002):
  y = val['Class'] 
  cov = EllipticEnvelope(support_fraction = TryRE, contamination = val_contamination)
  cov.fit(train_df)
  y_pred = cov.predict(val_df)
  y_pred_ee = [1 if i==-1 else 0 for i in y_pred]
  macro_f1 = f1_score(y, y_pred_ee, average='macro')
  
  print("F1 score on test", round(macro_f1,5), " with support_fraction ", TryRE)
  EpsF1.append([TryRE, round(macro_f1,5)])
    
EpsF1df = pd.DataFrame(EpsF1, columns = ['SupFrac', 'F1'])
EpsF1df.head()

# %%
EpsF1df.plot.line("SupFrac","F1")
plt.xlim(minRE, maxRE)
plt.title("F1 vs SupFrac")
plt.show()

# %% [markdown]
# ## Model

# %%
anom = setup(train.drop(columns=['ID'], axis=1),
             normalize = True,
             silent = True)
# Out:
#                                Description                 Value
# 0                               session_id                  8170
# 1                            Original Data          (113842, 30)
# 2                           Missing Values                 False
# 3                         Numeric Features                    30
# 4                     Categorical Features                     0
# 5                         Ordinal Features                 False
# 6                High Cardinality Features                 False
# 7                  High Cardinality Method                  None
# 8                         Transformed Data          (113842, 30)
# 9                                 CPU Jobs                    -1
# 10                                 Use GPU                 False
# 11                          Log Experiment                 False
# 12                         Experiment Name  anomaly-default-name
# 13                                     USI                  3de5
# 14                         Imputation Type                simple
# 15          Iterative Imputation Iteration                  None
# 16                         Numeric Imputer                  mean
# 17      Iterative Imputation Numeric Model                  None
# 18                     Categorical Imputer                  mode
# 19  Iterative Imputation Categorical Model                  None
# 20           Unknown Categoricals Handling        least_frequent
# 21                               Normalize                  True
# 22                        Normalize Method                zscore
# 23                          Transformation                 False
# 24                   Transformation Method                  None
# 25                                     PCA                 False
# 26                              PCA Method                  None
# 27                          PCA Components                  None
# 28                     Ignore Low Variance                 False
# 29                     Combine Rare Levels                 False
# 30                    Rare Level Threshold                  None
# 31                         Numeric Binning                 False
# 32                         Remove Outliers                 False
# 33                      Outliers Threshold                  None
# 34                Remove Multicollinearity                 False
# 35             Multicollinearity Threshold                  None
# 36             Remove Perfect Collinearity                 False
# 37                              Clustering                 False
# 38                    Clustering Iteration                  None
# 39                     Polynomial Features                 False
# 40                       Polynomial Degree                  None
# 41                    Trignometry Features                 False
# 42                    Polynomial Threshold                  None
# 43                          Group Features                 False
# 44                       Feature Selection                 False
# 45                Feature Selection Method               classic
# 46            Features Selection Threshold                  None
# 47                     Feature Interaction                 False
# 48                           Feature Ratio                 False
# 49                   Interaction Threshold                  None
# INFO:logs:create_model_container: 0
# INFO:logs:master_model_container: 0
# INFO:logs:display_container: 1
# INFO:logs:Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[],
#                                       target='UNSUPERVISED_DUMMY_TARGET',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='most frequent',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=Non...
#                 ('P_transform', 'passthrough'), ('binn', 'passthrough'),
#                 ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='UNSUPERVISED_DUMMY_TARGET')),
#                 ('fix_perfect', 'passthrough'),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# INFO:logs:setup() succesfully completed......................................

# %%
models()
# iforest, knn, svm, lof, pca
# Out:
# INFO:logs:gpu_param set to False
#                                         Name                    Reference
# ID
# abod            Angle-base Outlier Detection        pyod.models.abod.ABOD
# cluster       Clustering-Based Local Outlier      pyod.models.cblof.CBLOF
# cof         Connectivity-Based Local Outlier          pyod.models.cof.COF
# iforest                     Isolation Forest  pyod.models.iforest.IForest
# histogram  Histogram-based Outlier Detection        pyod.models.hbos.HBOS
# knn             K-Nearest Neighbors Detector          pyod.models.knn.KNN
# lof                     Local Outlier Factor          pyod.models.lof.LOF
# svm                   One-class SVM detector      pyod.models.ocsvm.OCSVM
# pca             Principal Component Analysis          pyod.models.pca.PCA
# mcd           Minimum Covariance Determinant          pyod.models.mcd.MCD
# sod               Subspace Outlier Detection          pyod.models.sod.SOD
# sos             Stochastic Outlier Selection          pyod.models.sos.SOS

# %%
# fraction = amount of outliers (assume same as the val dataset)

start_time = time.time()
anom_model = create_model(model = 'iforest',
                         fraction = np.round(val_contamination, 6))
end_time = time.time()
print("Time elapsed: %ds"%(end_time - start_time))

iforest_val_pred = predict_model(anom_model, data = val.drop(columns=['ID', 'Class'], axis=1))
# Out:
# INFO:logs:create_model_container: 1
# INFO:logs:master_model_container: 1
# INFO:logs:display_container: 2
# INFO:logs:IForest(behaviour='new', bootstrap=False, contamination=0.001055,
#     max_features=1.0, max_samples='auto', n_estimators=100, n_jobs=-1,
#     random_state=6989, verbose=0)
# INFO:logs:create_model() succesfully completed......................................
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=IForest(behaviour='new', bootstrap=False, contamination=0.001055,
#     max_features=1.0, max_samples='auto', n_estimators=100, n_jobs=-1,
#     random_state=6989, verbose=0), ml_usecase=MLUsecase.ANOMALY)
# Time elapsed: 17s

# %% [markdown]
# 왜인지 KNN, LOF은 학습이 오래걸림 (5~7분이상)

# %%
start_time = time.time()
anom_model = create_model(model = 'knn',
                         fraction = np.round(val_contamination, 6))
end_time = time.time()
print("Time elapsed: %ds"%(end_time - start_time))

knn_val_pred = predict_model(anom_model, data = val.drop(columns=['ID', 'Class'], axis=1))
# Out:
# INFO:logs:create_model_container: 1
# INFO:logs:master_model_container: 1
# INFO:logs:display_container: 2
# INFO:logs:KNN(algorithm='auto', contamination=0.001055, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#   radius=1.0)
# INFO:logs:create_model() succesfully completed......................................
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=KNN(algorithm='auto', contamination=0.001055, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#   radius=1.0), ml_usecase=MLUsecase.ANOMALY)
# Time elapsed: 369s

# %%
start_time = time.time()
anom_model = create_model(model = 'lof',
                         fraction = np.round(val_contamination, 6))
end_time = time.time()
print("Time elapsed: %ds"%(end_time - start_time))

lof_val_pred = predict_model(anom_model, data = val.drop(columns=['ID', 'Class'], axis=1))
# Out:
# INFO:logs:create_model_container: 1
# INFO:logs:master_model_container: 1
# INFO:logs:display_container: 2
# INFO:logs:LOF(algorithm='auto', contamination=0.001055, leaf_size=30,
#   metric='minkowski', metric_params=None, n_jobs=-1, n_neighbors=20,
#   novelty=True, p=2)
# INFO:logs:create_model() succesfully completed......................................
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=LOF(algorithm='auto', contamination=0.001055, leaf_size=30,
#   metric='minkowski', metric_params=None, n_jobs=-1, n_neighbors=20,
#   novelty=True, p=2), ml_usecase=MLUsecase.ANOMALY)
# Time elapsed: 523s

# %%
results = assign_model(anom_model)
results.head()

# %%
results['Anomaly'].value_counts()

# %%
# plot_model(anom_model, plot = 'umap')

# %%
# check f1 with validation data
# Out:
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=IForest(behaviour='new', bootstrap=False, contamination=0.0010551491277433877,
#     max_features=1.0, max_samples='auto', n_estimators=100, n_jobs=-1,
#     random_state=7293, verbose=0), ml_usecase=MLUsecase.ANOMALY)

# %%
val_pred_data = val.drop(columns=['Class'])
val_pred_data['Class'] = iforest_val_pred['Anomaly']
#val_pred_data
y_true = val['Class']
y_pred = val_pred_data['Class']

f1_score(y_true, y_pred, average='macro')
# Out:
# 0.6926747205467729

# %%
val_pred_data = val.drop(columns=['Class'])
val_pred_data['Class'] = knn_val_pred['Anomaly']
#val_pred_data
y_true = val['Class']
y_pred = val_pred_data['Class']

f1_score(y_true, y_pred, average='macro')
# Out:
# 0.5531318140254624

# %%
val_pred_data = val.drop(columns=['Class'], axis=1)
val_pred_data['Class'] = lof_val_pred['Anomaly']
#val_pred_data
y_true = val['Class']
y_pred = val_pred_data['Class']

f1_score(y_true, y_pred, average='macro')
# Out:
# 0.4994636230941034

# %% [markdown]
# ## Prediction

# %%
clf = LocalOutlierFactor(n_neighbors=700, contamination = val_contamination, novelty=True)
clf.fit(train_df)
pred = clf.predict(test_df)
prediction = [1 if i==-1 else 0 for i in pred]

# %%
#pd.set_option('max_rows', 10)
submission = pd.read_csv('sample_submission.csv')
submission['Class'] = prediction
submission
# Out:
#              ID  Class
# 0       AAAA0x1      0
# 1       AAAA0x2      0
# 2       AAAA0x5      0
# 3       AAAA0x7      0
# 4       AAAA0xc      0
# ...         ...    ...
# 142498  0x4587f      0
# 142499  0x45880      0
# 142500  0x45884      0
# 142501  0x45885      0
# 142502  0x45887      0
#
# [142503 rows x 2 columns]

# %%
submission['Class'].value_counts()
# Out:
# 0    142337
# 1       166
# Name: Class, dtype: int64

# %%
submission.to_csv('sub.csv', index=False)
